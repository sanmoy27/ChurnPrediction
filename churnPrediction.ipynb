# %%
import pandas as pd
import os
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, FunctionTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
from xgboost import XGBClassifier
import optuna

# %%
# ! pip install xgboost
# ! pip install optuna
# ! pip install lightgbm

# %% [markdown]
# ## Read Data

# %%
train_df = pd.read_csv(os.path.join('data', 'train.csv'))
label_df = pd.read_csv(os.path.join('data', 'train_churn_labels.csv'))

train_fnl_df = pd.concat([train_df, label_df], axis=1)

# %%
train_fnl_df.shape
# Out:
# (50000, 231)

# %%
train_fnl_df.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  ...  \
# 0   NaN   NaN   NaN   NaN   NaN  1526.0   7.0   NaN   NaN    NaN  ...
# 1   NaN   NaN   NaN   NaN   NaN   525.0   0.0   NaN   NaN    NaN  ...
# 2   NaN   NaN   NaN   NaN   NaN  5236.0   7.0   NaN   NaN    NaN  ...
# 3   NaN   NaN   NaN   NaN   NaN     NaN   0.0   NaN   NaN    NaN  ...
# 4   NaN   NaN   NaN   NaN   NaN  1029.0   7.0   NaN   NaN    NaN  ...
#
#     Var222      Var223  Var224  Var225  Var226   Var227         Var228  \
# 0  fXVEsaq  jySVZNlOJy     NaN     NaN    xb3V     RAYp  F2FyR07IdsN7I
# 1  2Kb5FSF  LM8l689qOp     NaN     NaN    fKCe     RAYp  F2FyR07IdsN7I
# 2  NKv4yOc  jySVZNlOJy     NaN    kG3k    Qu4f  02N6s8f  ib5G6X1eUxUn6
# 3  CE7uk3u  LM8l689qOp     NaN     NaN    FSa2     RAYp  F2FyR07IdsN7I
# 4  1J2cvxe  LM8l689qOp     NaN    kG3k    FSa2     RAYp  F2FyR07IdsN7I
#
#    Var229  Var230  Label
# 0     NaN     NaN     -1
# 1     NaN     NaN      1
# 2    am7c     NaN     -1
# 3     NaN     NaN     -1
# 4    mj86     NaN     -1
#
# [5 rows x 231 columns]

# %%
train_fnl_df["Label"] = train_fnl_df["Label"].replace({-1: 0, 1: 1})

# %%
train_fnl_df["Label"].value_counts(normalize=True)
# Out:
# Label
# 0    0.92656
# 1    0.07344
# Name: proportion, dtype: float64

# %% [markdown]
# ## Drop columns cols having null values greater than 50%

# %%
def missing_values(df):
    """
    Returns a DataFrame with the count and percentage of missing values in each column.
    """
    total = df.isnull().sum()
    percent = (total / len(df)) * 100

    mis_val_tbl = pd.concat([total, percent], axis=1)
    mis_val_tbl.columns = ['Missing Values', 'Percentage']

    mis_val_tbl = mis_val_tbl[mis_val_tbl.iloc[:,1]!=0].sort_values('Percentage', ascending=False)
    return mis_val_tbl.reset_index()

# %%
miss_df = missing_values(train_fnl_df)

# %%
drop_cols = miss_df[miss_df["Percentage"]>50]["index"].values

# %%
train_fnl_df.drop(columns=drop_cols, inplace=True)

# %%
train_fnl_df.shape
# Out:
# (50000, 70)

# %%
X = train_fnl_df.drop(columns=["Label"])
y = train_fnl_df["Label"]

# %%
num_cols = X.select_dtypes(include=np.number).columns.tolist()
cat_cols = X.select_dtypes(include="object").columns.tolist()

# %% [markdown]
# ## Feature Eng using sklearn pipeline

# %%
class MultiColumnLabelEncoder(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoders = {}
        self.feature_names_in_ = None

    def fit(self, X, y=None):
        # If input is ndarray, use feature_names_in_ if set, else fallback to range
        if isinstance(X, np.ndarray):
            if self.feature_names_in_ is not None:
                X = pd.DataFrame(X, columns=self.feature_names_in_)
            else:
                X = pd.DataFrame(X)
        self.feature_names_in_ = list(getattr(X, 'columns', []))
        for col in X.columns:
            le = LabelEncoder()
            le.fit(X[col].astype(str))
            self.encoders[col] = le
        return self

    def transform(self, X):
        if isinstance(X, np.ndarray):
            X = pd.DataFrame(X, columns=self.feature_names_in_)
        X_encoded = X.copy()
        for col in X.columns:
            X_encoded[col] = self.encoders[col].transform(X_encoded[col].astype(str))
        return X_encoded

    def get_feature_names_out(self, input_features=None):
        if self.feature_names_in_ is not None:
            return list(self.feature_names_in_)
        elif input_features is not None:
            return list(input_features)
        else:
            return None

# %%
class DropCorrelatedFeatures(BaseEstimator, TransformerMixin):
    def __init__(self, threshold=0.7):
        self.threshold = threshold
        self.to_drop_ = None
        self.feature_names_in_ = None

    def fit(self, X, y=None):
        if isinstance(X, np.ndarray):
            if self.feature_names_in_ is not None:
                X = pd.DataFrame(X, columns=self.feature_names_in_)
            else:
                X = pd.DataFrame(X)
        self.feature_names_in_ = list(getattr(X, 'columns', []))
        corr_matrix = X.corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        self.to_drop_ = [column for column in upper.columns if any(upper[column] > self.threshold)]
        return self

    def transform(self, X):
        if isinstance(X, np.ndarray):
            X = pd.DataFrame(X, columns=self.feature_names_in_)
        return X.drop(columns=self.to_drop_, errors='ignore')

    def get_feature_names_out(self, input_features=None):
        if self.feature_names_in_ is None:
            return None
        return [col for col in self.feature_names_in_ if col not in (self.to_drop_ or [])]

# %%
preprocessor = ColumnTransformer([
    ("num_imputer", SimpleImputer(strategy="mean"), num_cols),
    ("cat_imputer", SimpleImputer(strategy="most_frequent"), cat_cols),
], remainder="drop")

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler

# Numeric pipeline: impute, scale, then drop correlated features
num_pipeline = make_pipeline(
    SimpleImputer(strategy="mean"),
    StandardScaler(),
    DropCorrelatedFeatures(threshold=0.7)
 )

# Categorical pipeline: impute then label encode (use MultiColumnLabelEncoder directly)
cat_pipeline = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    MultiColumnLabelEncoder()
 )

# ColumnTransformer to apply pipelines
preprocessor = make_column_transformer(
    (num_pipeline, num_cols),
    (cat_pipeline, cat_cols),
    remainder="drop"
 )

pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("rf", RandomForestClassifier(random_state=42))
 ])

# Ensure all pipeline steps output pandas DataFrames
pipeline.set_output(transform="pandas")
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler()),
#                                                                   ('dropcorrelatedfeatures',
#                                                                    DropCorrelatedFeatures())]),
#                                                   ['Var6', 'Var7', 'Var13',
#                                                    'Var21', 'Var22', 'Var24',
#                                                    'Var25', 'Var28', 'Var35',
#                                                    'Var38', 'Var44', 'Var57',
#                                                    'Var65', 'Var72', 'Var73',
#                                                    'Var74', 'Var7...
#                                                                   ('multicolumnlabelencoder',
#                                                                    MultiColumnLabelEncoder())]),
#                                                   ['Var192', 'Var193', 'Var195',
#                                                    'Var196', 'Var197', 'Var198',
#                                                    'Var199', 'Var202', 'Var203',
#                                                    'Var204', 'Var205', 'Var206',
#                                                    'Var207', 'Var208', 'Var210',
#                                                    'Var211', 'Var212', 'Var216',
#                                                    'Var217', 'Var218', 'Var219',
#                                                    'Var220', 'Var221', 'Var222',
#                                                    'Var223', 'Var226', 'Var227',
#                                                    'Var228'])])),
#                 ('rf', RandomForestClassifier(random_state=42))])

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler()),
#                                                                   ('dropcorrelatedfeatures',
#                                                                    DropCorrelatedFeatures())]),
#                                                   ['Var6', 'Var7', 'Var13',
#                                                    'Var21', 'Var22', 'Var24',
#                                                    'Var25', 'Var28', 'Var35',
#                                                    'Var38', 'Var44', 'Var57',
#                                                    'Var65', 'Var72', 'Var73',
#                                                    'Var74', 'Var7...
#                                                                   ('multicolumnlabelencoder',
#                                                                    MultiColumnLabelEncoder())]),
#                                                   ['Var192', 'Var193', 'Var195',
#                                                    'Var196', 'Var197', 'Var198',
#                                                    'Var199', 'Var202', 'Var203',
#                                                    'Var204', 'Var205', 'Var206',
#                                                    'Var207', 'Var208', 'Var210',
#                                                    'Var211', 'Var212', 'Var216',
#                                                    'Var217', 'Var218', 'Var219',
#                                                    'Var220', 'Var221', 'Var222',
#                                                    'Var223', 'Var226', 'Var227',
#                                                    'Var228'])])),
#                 ('rf', RandomForestClassifier(random_state=42))])

# %%
# Get numeric feature names after DropCorrelatedFeatures
num_feature_names = pipeline.named_steps['preprocessor'].transformers_[0][1].named_steps['dropcorrelatedfeatures'].get_feature_names_out()

# Get categorical feature names after MultiColumnLabelEncoder
cat_feature_names = pipeline.named_steps['preprocessor'].transformers_[1][1].named_steps['multicolumnlabelencoder'].get_feature_names_out()

# Combine feature names
all_feature_names = list(num_feature_names) + list(cat_feature_names)

# %%
all_feature_names
# Out:
# ['Var6',
#  'Var7',
#  'Var13',
#  'Var21',
#  'Var24',
#  'Var28',
#  'Var35',
#  'Var38',
#  'Var44',
#  'Var57',
#  'Var65',
#  'Var72',
#  'Var73',
#  'Var74',
#  'Var76',
#  'Var78',
#  'Var81',
#  'Var94',
#  'Var113',
#  'Var125',
#  'Var126',
#  'Var133',
#  'Var134',
#  'Var140',
#  'Var143',
#  'Var144',
#  'Var149',
#  'Var153',
#  'Var163',
#  'Var173',
#  'Var181',
#  'Var192',
#  'Var193',
#  'Var195',
#  'Var196',
#  'Var197',
#  'Var198',
#  'Var199',
#  'Var202',
#  'Var203',
#  'Var204',
#  'Var205',
#  'Var206',
#  'Var207',
#  'Var208',
#  'Var210',
#  'Var211',
#  'Var212',
#  'Var216',
#  'Var217',
#  'Var218',
#  'Var219',
#  'Var220',
#  'Var221',
#  'Var222',
#  'Var223',
#  'Var226',
#  'Var227',
#  'Var228']

# %% [markdown]
# ## Get Feature Importance

# %%
importances = pipeline.named_steps["rf"].feature_importances_

feature_importance_df = pd.DataFrame({
    "feature": all_feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

feature_importance_df
# Out:
#    feature  importance
# 18  Var113    0.040832
# 9    Var57    0.036914
# 37  Var199    0.036065
# 38  Var202    0.035203
# 49  Var217    0.034256
# 54  Var222    0.033885
# 36  Var198    0.033775
# 52  Var220    0.033613
# 20  Var126    0.032581
# 31  Var192    0.032443
# 40  Var204    0.028750
# 16   Var81    0.028718
# 27  Var153    0.028467
# 0     Var6    0.027725
# 35  Var197    0.027380
# 48  Var216    0.026044
# 21  Var133    0.025882
# 12   Var73    0.025762
# 3    Var21    0.025312
# 22  Var134    0.024965
# 5    Var28    0.024676
# 7    Var38    0.024185
# 14   Var76    0.024037
# 17   Var94    0.023719
# 56  Var226    0.023219
# 19  Var125    0.022364
# 28  Var163    0.020146
# 2    Var13    0.019968
# 26  Var149    0.018860
# 23  Var140    0.018752
# 4    Var24    0.012407
# 13   Var74    0.012024
# 42  Var206    0.011408
# 41  Var205    0.010625
# 25  Var144    0.010164
# 47  Var212    0.008466
# 10   Var65    0.007587
# 11   Var72    0.006927
# 58  Var228    0.006088
# 6    Var35    0.005378
# 1     Var7    0.005356
# 51  Var219    0.005181
# 50  Var218    0.005111
# 43  Var207    0.005045
# 15   Var78    0.005021
# 57  Var227    0.005020
# 32  Var193    0.004953
# 45  Var210    0.004793
# 53  Var221    0.004251
# 55  Var223    0.003924
# 30  Var181    0.003720
# 39  Var203    0.003701
# 46  Var211    0.003458
# 44  Var208    0.002912
# 33  Var195    0.002347
# 24  Var143    0.001622
# 8    Var44    0.001613
# 34  Var196    0.001369
# 29  Var173    0.001034

# %% [markdown]
# ## Select Features having 80% importance

# %%
# Calculate cumulative importance
feature_importance_df = feature_importance_df.reset_index(drop=True)
feature_importance_df['cumulative_importance'] = feature_importance_df['importance'].cumsum()

# Select features that capture 80% of the importance
selected_features = feature_importance_df[feature_importance_df['cumulative_importance'] <= 0.8]['feature'].tolist()
# If not enough features, include the next one to cross 80%
if len(selected_features) < len(feature_importance_df):
    selected_features.append(feature_importance_df.iloc[len(selected_features)]['feature'])

# %%
len(selected_features)
# Out:
# 28

# %% [markdown]
# ## Modeling

# %%
# Get the transformed features (as a pandas DataFrame)
X_transformed = pipeline.named_steps["preprocessor"].transform(X)

# Remove pipeline prefixes from column names if present
def strip_pipeline_prefix(col):
    if isinstance(col, str) and "__" in col:
        return col.split("__", 1)[-1]
    return col

X_transformed.columns = [strip_pipeline_prefix(col) for col in X_transformed.columns]

X_transformed_df = X_transformed
X_transformed_df
# Out:
#            Var6          Var7     Var13         Var21     Var24         Var28  \
# 0      0.078791  3.193535e-02 -0.404348  4.302500e-01  1.033675 -6.200792e-01
# 1     -0.316420 -1.141517e+00 -0.474163 -1.247134e-01 -0.273110  1.380519e+00
# 2      1.543559  3.193535e-02 -0.131163  1.832657e+00  2.340460 -4.737905e-02
# 3      0.000000 -1.141517e+00 -0.474163  5.328719e-17  0.000000 -2.166113e+00
# 4     -0.117433  3.193535e-02  0.746067 -3.197006e-01 -0.055313 -2.622486e-01
# ...         ...           ...       ...           ...       ...           ...
# 49995 -0.382749 -1.141517e+00 -0.474163 -1.922090e-01 -0.273110  6.802669e-01
# 49996 -0.098087 -1.141517e+00  0.563943  2.727603e-01 -0.273110 -6.200792e-01
# 49997  0.584550  3.193535e-02  0.079797  6.252371e-01 -0.055313 -6.200792e-01
# 49998  0.000000 -1.488907e-16  0.000000  5.328719e-17  0.000000  3.041315e-16
# 49999  0.145120  3.193535e-02 -0.159999 -7.971642e-02 -0.490907 -4.737905e-02
#
#               Var35     Var38     Var44     Var57  ...  Var217  Var218  \
# 0     -2.522251e-01 -0.902022 -0.107944  0.278694  ...   12236       1
# 1     -2.522251e-01  0.765547 -0.107944  0.935760  ...    9781       1
# 2     -2.522251e-01  1.157425 -0.107944  1.523967  ...    8473       0
# 3     -2.522251e-01 -0.903273 -0.107944 -0.752303  ...    9161       0
# 4     -2.522251e-01 -0.903273 -0.107944  0.513428  ...    3834       0
# ...             ...       ...       ...       ...  ...     ...     ...
# 49995 -2.522251e-01  1.212945 -0.107944 -0.372362  ...    7428       1
# 49996 -2.522251e-01 -0.903273 -0.107944 -1.440056  ...    1059       0
# 49997 -2.522251e-01 -0.888490 -0.107944  1.511313  ...    3040       0
# 49998 -3.906559e-17  0.000000  0.000000  1.505408  ...    1874       0
# 49999  1.507133e+00  0.039268 -0.107944 -1.173580  ...   10438       1
#
#        Var219  Var220  Var221  Var222  Var223  Var226  Var227  Var228
# 0          11      94       4    2964       3      22       2       8
# 1          11      10       4     125       0      14       2       8
# 2          11    1293       0    1610       3      10       0      25
# 3          11    1444       4     817       0       7       2       8
# 4          11    1731       4      65       0       7       2       8
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 49995      11     257       4     969       0       3       2       8
# 49996      11    1512       4    1125       0       7       2       2
# 49997      11    1041       4    2834       0      14       2      14
# 49998      11     837       4     142       0       7       2       8
# 49999      11    3621       4    1262       0      22       2       8
#
# [50000 rows x 59 columns]

# %%
X_transformed_df
# Out:
#            Var6          Var7     Var13         Var21     Var24         Var28  \
# 0      0.078791  3.193535e-02 -0.404348  4.302500e-01  1.033675 -6.200792e-01
# 1     -0.316420 -1.141517e+00 -0.474163 -1.247134e-01 -0.273110  1.380519e+00
# 2      1.543559  3.193535e-02 -0.131163  1.832657e+00  2.340460 -4.737905e-02
# 3      0.000000 -1.141517e+00 -0.474163  5.328719e-17  0.000000 -2.166113e+00
# 4     -0.117433  3.193535e-02  0.746067 -3.197006e-01 -0.055313 -2.622486e-01
# ...         ...           ...       ...           ...       ...           ...
# 49995 -0.382749 -1.141517e+00 -0.474163 -1.922090e-01 -0.273110  6.802669e-01
# 49996 -0.098087 -1.141517e+00  0.563943  2.727603e-01 -0.273110 -6.200792e-01
# 49997  0.584550  3.193535e-02  0.079797  6.252371e-01 -0.055313 -6.200792e-01
# 49998  0.000000 -1.488907e-16  0.000000  5.328719e-17  0.000000  3.041315e-16
# 49999  0.145120  3.193535e-02 -0.159999 -7.971642e-02 -0.490907 -4.737905e-02
#
#               Var35     Var38     Var44     Var57  ...  Var217  Var218  \
# 0     -2.522251e-01 -0.902022 -0.107944  0.278694  ...   12236       1
# 1     -2.522251e-01  0.765547 -0.107944  0.935760  ...    9781       1
# 2     -2.522251e-01  1.157425 -0.107944  1.523967  ...    8473       0
# 3     -2.522251e-01 -0.903273 -0.107944 -0.752303  ...    9161       0
# 4     -2.522251e-01 -0.903273 -0.107944  0.513428  ...    3834       0
# ...             ...       ...       ...       ...  ...     ...     ...
# 49995 -2.522251e-01  1.212945 -0.107944 -0.372362  ...    7428       1
# 49996 -2.522251e-01 -0.903273 -0.107944 -1.440056  ...    1059       0
# 49997 -2.522251e-01 -0.888490 -0.107944  1.511313  ...    3040       0
# 49998 -3.906559e-17  0.000000  0.000000  1.505408  ...    1874       0
# 49999  1.507133e+00  0.039268 -0.107944 -1.173580  ...   10438       1
#
#        Var219  Var220  Var221  Var222  Var223  Var226  Var227  Var228
# 0          11      94       4    2964       3      22       2       8
# 1          11      10       4     125       0      14       2       8
# 2          11    1293       0    1610       3      10       0      25
# 3          11    1444       4     817       0       7       2       8
# 4          11    1731       4      65       0       7       2       8
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 49995      11     257       4     969       0       3       2       8
# 49996      11    1512       4    1125       0       7       2       2
# 49997      11    1041       4    2834       0      14       2      14
# 49998      11     837       4     142       0       7       2       8
# 49999      11    3621       4    1262       0      22       2       8
#
# [50000 rows x 59 columns]

# %%
selected_features
# Out:
# ['Var113',
#  'Var57',
#  'Var199',
#  'Var202',
#  'Var217',
#  'Var222',
#  'Var198',
#  'Var220',
#  'Var126',
#  'Var192',
#  'Var204',
#  'Var81',
#  'Var153',
#  'Var6',
#  'Var197',
#  'Var216',
#  'Var133',
#  'Var73',
#  'Var21',
#  'Var134',
#  'Var28',
#  'Var38',
#  'Var76',
#  'Var94',
#  'Var226',
#  'Var125',
#  'Var163',
#  'Var13']

# %%
X_selected = X_transformed_df[selected_features]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y, test_size=0.3, random_state=42)

# %%
print(f"Shape of training data: {X_train.shape},\nShape of test data: {X_test.shape}")
# Out:
# Shape of training data: (35000, 28),
# Shape of test data: (15000, 28)

# %% [markdown]
# ## XG Boost Model

# %%
# Fit XGBoost
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
xgb_model.fit(X_train, y_train)
# Out:
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:36:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ## Train Prediction

# %%
y_train_pred = xgb_model.predict(X_train)

# Classification report
print("Classification Report:\n", classification_report(y_train, y_train_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     32434
#            1       1.00      0.50      0.67      2566
#
#     accuracy                           0.96     35000
#    macro avg       0.98      0.75      0.82     35000
# weighted avg       0.96      0.96      0.96     35000

# %% [markdown]
# ## Test Prediction

# %%
y_test_pred = xgb_model.predict(X_test)
y_test_pred_proba = xgb_model.predict_proba(X_test)[:, 1]

# Classification report
print("Classification Report:\n", classification_report(y_test, y_test_pred))

# AUC-ROC score
auc = roc_auc_score(y_test, y_test_pred_proba)
print(f"AUC-ROC Score: {auc:.4f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     13894
#            1       0.39      0.03      0.05      1106
#
#     accuracy                           0.93     15000
#    macro avg       0.66      0.51      0.51     15000
# weighted avg       0.89      0.93      0.89     15000
#
# AUC-ROC Score: 0.6737

# %% [markdown]
# ## Hyper-param Tuning

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 5),
        'random_state': 42,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }
    model = XGBClassifier(**params)
    model.fit(X_train, y_train)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred_proba)
    return auc

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)

print('Best trial:')
print(study.best_trial.params)

# Train final model with best params
best_params = study.best_trial.params
best_params['random_state'] = 42
best_params['use_label_encoder'] = False
best_params['eval_metric'] = 'logloss'
# Out:
# [I 2025-07-15 23:37:00,161] A new study created in memory with name: no-name-c0f42d36-2d23-43aa-84ad-0fe1b28dfca3
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:01,158] Trial 0 finished with value: 0.7032047215666226 and parameters: {'n_estimators': 141, 'max_depth': 6, 'learning_rate': 0.1794771830847651, 'subsample': 0.6390778408722642, 'colsample_bytree': 0.7758005419768825, 'gamma': 4.024553112107021, 'reg_alpha': 1.6630340234170682, 'reg_lambda': 2.8122181407651374}. Best is trial 0 with value: 0.7032047215666226.
# [I 2025-07-15 23:37:01,158] Trial 0 finished with value: 0.7032047215666226 and parameters: {'n_estimators': 141, 'max_depth': 6, 'learning_rate': 0.1794771830847651, 'subsample': 0.6390778408722642, 'colsample_bytree': 0.7758005419768825, 'gamma': 4.024553112107021, 'reg_alpha': 1.6630340234170682, 'reg_lambda': 2.8122181407651374}. Best is trial 0 with value: 0.7032047215666226.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:01] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:01,947] Trial 1 finished with value: 0.7148160146143976 and parameters: {'n_estimators': 107, 'max_depth': 5, 'learning_rate': 0.21337149021178123, 'subsample': 0.9292735375734305, 'colsample_bytree': 0.5707076788252393, 'gamma': 4.548543797706267, 'reg_alpha': 3.9088421877436823, 'reg_lambda': 1.5331944385318215}. Best is trial 1 with value: 0.7148160146143976.
# [I 2025-07-15 23:37:01,947] Trial 1 finished with value: 0.7148160146143976 and parameters: {'n_estimators': 107, 'max_depth': 5, 'learning_rate': 0.21337149021178123, 'subsample': 0.9292735375734305, 'colsample_bytree': 0.5707076788252393, 'gamma': 4.548543797706267, 'reg_alpha': 3.9088421877436823, 'reg_lambda': 1.5331944385318215}. Best is trial 1 with value: 0.7148160146143976.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:03,816] Trial 2 finished with value: 0.7175950642568598 and parameters: {'n_estimators': 162, 'max_depth': 5, 'learning_rate': 0.031824541095912456, 'subsample': 0.7010538167267433, 'colsample_bytree': 0.6549069963597404, 'gamma': 2.3543886598976425, 'reg_alpha': 0.3660620914327045, 'reg_lambda': 4.515132765523073}. Best is trial 2 with value: 0.7175950642568598.
# [I 2025-07-15 23:37:03,816] Trial 2 finished with value: 0.7175950642568598 and parameters: {'n_estimators': 162, 'max_depth': 5, 'learning_rate': 0.031824541095912456, 'subsample': 0.7010538167267433, 'colsample_bytree': 0.6549069963597404, 'gamma': 2.3543886598976425, 'reg_alpha': 0.3660620914327045, 'reg_lambda': 4.515132765523073}. Best is trial 2 with value: 0.7175950642568598.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:04,684] Trial 3 finished with value: 0.7115678030846313 and parameters: {'n_estimators': 146, 'max_depth': 6, 'learning_rate': 0.2959385569489834, 'subsample': 0.7265888563678371, 'colsample_bytree': 0.6298535616876988, 'gamma': 4.291458375770887, 'reg_alpha': 4.911539942602199, 'reg_lambda': 2.848048664200216}. Best is trial 2 with value: 0.7175950642568598.
# [I 2025-07-15 23:37:04,684] Trial 3 finished with value: 0.7115678030846313 and parameters: {'n_estimators': 146, 'max_depth': 6, 'learning_rate': 0.2959385569489834, 'subsample': 0.7265888563678371, 'colsample_bytree': 0.6298535616876988, 'gamma': 4.291458375770887, 'reg_alpha': 4.911539942602199, 'reg_lambda': 2.848048664200216}. Best is trial 2 with value: 0.7175950642568598.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:06,249] Trial 4 finished with value: 0.7050722585444795 and parameters: {'n_estimators': 54, 'max_depth': 9, 'learning_rate': 0.0887970189880665, 'subsample': 0.7350919833662511, 'colsample_bytree': 0.6615712524875269, 'gamma': 0.1679077844291288, 'reg_alpha': 0.43961035044780716, 'reg_lambda': 0.9236391053778759}. Best is trial 2 with value: 0.7175950642568598.
# [I 2025-07-15 23:37:06,249] Trial 4 finished with value: 0.7050722585444795 and parameters: {'n_estimators': 54, 'max_depth': 9, 'learning_rate': 0.0887970189880665, 'subsample': 0.7350919833662511, 'colsample_bytree': 0.6615712524875269, 'gamma': 0.1679077844291288, 'reg_alpha': 0.43961035044780716, 'reg_lambda': 0.9236391053778759}. Best is trial 2 with value: 0.7175950642568598.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:07,909] Trial 5 finished with value: 0.6930914667525316 and parameters: {'n_estimators': 213, 'max_depth': 4, 'learning_rate': 0.28045767043776204, 'subsample': 0.6563639974434594, 'colsample_bytree': 0.8756748795545191, 'gamma': 2.3231813574768037, 'reg_alpha': 4.819431208326764, 'reg_lambda': 4.660466120822306}. Best is trial 2 with value: 0.7175950642568598.
# [I 2025-07-15 23:37:07,909] Trial 5 finished with value: 0.6930914667525316 and parameters: {'n_estimators': 213, 'max_depth': 4, 'learning_rate': 0.28045767043776204, 'subsample': 0.6563639974434594, 'colsample_bytree': 0.8756748795545191, 'gamma': 2.3231813574768037, 'reg_alpha': 4.819431208326764, 'reg_lambda': 4.660466120822306}. Best is trial 2 with value: 0.7175950642568598.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:08,950] Trial 6 finished with value: 0.6988162894933508 and parameters: {'n_estimators': 131, 'max_depth': 8, 'learning_rate': 0.26424350895284987, 'subsample': 0.7379181796655693, 'colsample_bytree': 0.8022531585429042, 'gamma': 4.196088982125959, 'reg_alpha': 3.8586838464242073, 'reg_lambda': 2.1311684112033076}. Best is trial 2 with value: 0.7175950642568598.
# [I 2025-07-15 23:37:08,950] Trial 6 finished with value: 0.6988162894933508 and parameters: {'n_estimators': 131, 'max_depth': 8, 'learning_rate': 0.26424350895284987, 'subsample': 0.7379181796655693, 'colsample_bytree': 0.8022531585429042, 'gamma': 4.196088982125959, 'reg_alpha': 3.8586838464242073, 'reg_lambda': 2.1311684112033076}. Best is trial 2 with value: 0.7175950642568598.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:10,139] Trial 7 finished with value: 0.7172251425218739 and parameters: {'n_estimators': 232, 'max_depth': 2, 'learning_rate': 0.20232039272430966, 'subsample': 0.6355024657349093, 'colsample_bytree': 0.5360359930173073, 'gamma': 4.716258561719052, 'reg_alpha': 3.50130542141714, 'reg_lambda': 4.45790336307942}. Best is trial 2 with value: 0.7175950642568598.
# [I 2025-07-15 23:37:10,139] Trial 7 finished with value: 0.7172251425218739 and parameters: {'n_estimators': 232, 'max_depth': 2, 'learning_rate': 0.20232039272430966, 'subsample': 0.6355024657349093, 'colsample_bytree': 0.5360359930173073, 'gamma': 4.716258561719052, 'reg_alpha': 3.50130542141714, 'reg_lambda': 4.45790336307942}. Best is trial 2 with value: 0.7175950642568598.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:11,549] Trial 8 finished with value: 0.718295309279169 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.09646400244102554, 'subsample': 0.9754162828869344, 'colsample_bytree': 0.8048684481028019, 'gamma': 0.3062788063269073, 'reg_alpha': 4.657201546119879, 'reg_lambda': 1.7096673920891314}. Best is trial 8 with value: 0.718295309279169.
# [I 2025-07-15 23:37:11,549] Trial 8 finished with value: 0.718295309279169 and parameters: {'n_estimators': 187, 'max_depth': 4, 'learning_rate': 0.09646400244102554, 'subsample': 0.9754162828869344, 'colsample_bytree': 0.8048684481028019, 'gamma': 0.3062788063269073, 'reg_alpha': 4.657201546119879, 'reg_lambda': 1.7096673920891314}. Best is trial 8 with value: 0.718295309279169.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:13,232] Trial 9 finished with value: 0.7139252284996374 and parameters: {'n_estimators': 281, 'max_depth': 2, 'learning_rate': 0.20909199523743852, 'subsample': 0.689097248147532, 'colsample_bytree': 0.8877071717803193, 'gamma': 3.350217935475791, 'reg_alpha': 0.9221246015521622, 'reg_lambda': 4.1763667929832105}. Best is trial 8 with value: 0.718295309279169.
# [I 2025-07-15 23:37:13,232] Trial 9 finished with value: 0.7139252284996374 and parameters: {'n_estimators': 281, 'max_depth': 2, 'learning_rate': 0.20909199523743852, 'subsample': 0.689097248147532, 'colsample_bytree': 0.8877071717803193, 'gamma': 3.350217935475791, 'reg_alpha': 0.9221246015521622, 'reg_lambda': 4.1763667929832105}. Best is trial 8 with value: 0.718295309279169.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:17,409] Trial 10 finished with value: 0.686405088280135 and parameters: {'n_estimators': 210, 'max_depth': 10, 'learning_rate': 0.11976036703047087, 'subsample': 0.9968476258574716, 'colsample_bytree': 0.9968222864405174, 'gamma': 0.17268929959566703, 'reg_alpha': 2.635050550239568, 'reg_lambda': 0.14708629512792548}. Best is trial 8 with value: 0.718295309279169.
# [I 2025-07-15 23:37:17,409] Trial 10 finished with value: 0.686405088280135 and parameters: {'n_estimators': 210, 'max_depth': 10, 'learning_rate': 0.11976036703047087, 'subsample': 0.9968476258574716, 'colsample_bytree': 0.9968222864405174, 'gamma': 0.17268929959566703, 'reg_alpha': 2.635050550239568, 'reg_lambda': 0.14708629512792548}. Best is trial 8 with value: 0.718295309279169.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:18,684] Trial 11 finished with value: 0.7120470516759416 and parameters: {'n_estimators': 184, 'max_depth': 4, 'learning_rate': 0.014484684545755827, 'subsample': 0.5203289489479686, 'colsample_bytree': 0.7194362087386171, 'gamma': 1.5403560446488873, 'reg_alpha': 2.0654875318081105, 'reg_lambda': 3.6947238638029747}. Best is trial 8 with value: 0.718295309279169.
# [I 2025-07-15 23:37:18,684] Trial 11 finished with value: 0.7120470516759416 and parameters: {'n_estimators': 184, 'max_depth': 4, 'learning_rate': 0.014484684545755827, 'subsample': 0.5203289489479686, 'colsample_bytree': 0.7194362087386171, 'gamma': 1.5403560446488873, 'reg_alpha': 2.0654875318081105, 'reg_lambda': 3.6947238638029747}. Best is trial 8 with value: 0.718295309279169.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:20,432] Trial 12 finished with value: 0.7207621266260092 and parameters: {'n_estimators': 275, 'max_depth': 4, 'learning_rate': 0.034228658246875605, 'subsample': 0.8776240621501177, 'colsample_bytree': 0.6815849222162875, 'gamma': 1.3981324088315588, 'reg_alpha': 0.06636322347264312, 'reg_lambda': 3.4148203528722587}. Best is trial 12 with value: 0.7207621266260092.
# [I 2025-07-15 23:37:20,432] Trial 12 finished with value: 0.7207621266260092 and parameters: {'n_estimators': 275, 'max_depth': 4, 'learning_rate': 0.034228658246875605, 'subsample': 0.8776240621501177, 'colsample_bytree': 0.6815849222162875, 'gamma': 1.3981324088315588, 'reg_alpha': 0.06636322347264312, 'reg_lambda': 3.4148203528722587}. Best is trial 12 with value: 0.7207621266260092.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:21,997] Trial 13 finished with value: 0.72048031713118 and parameters: {'n_estimators': 283, 'max_depth': 3, 'learning_rate': 0.06399962124308847, 'subsample': 0.8568846336879077, 'colsample_bytree': 0.8378953934906735, 'gamma': 1.1070392091373078, 'reg_alpha': 2.8460491822158724, 'reg_lambda': 3.4618802127302817}. Best is trial 12 with value: 0.7207621266260092.
# [I 2025-07-15 23:37:21,997] Trial 13 finished with value: 0.72048031713118 and parameters: {'n_estimators': 283, 'max_depth': 3, 'learning_rate': 0.06399962124308847, 'subsample': 0.8568846336879077, 'colsample_bytree': 0.8378953934906735, 'gamma': 1.1070392091373078, 'reg_alpha': 2.8460491822158724, 'reg_lambda': 3.4618802127302817}. Best is trial 12 with value: 0.7207621266260092.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:23,919] Trial 14 finished with value: 0.7210585781105248 and parameters: {'n_estimators': 290, 'max_depth': 3, 'learning_rate': 0.05539265783834485, 'subsample': 0.8617002750807236, 'colsample_bytree': 0.9127617299817429, 'gamma': 1.299996297362331, 'reg_alpha': 2.9353858127133168, 'reg_lambda': 3.3173297789608567}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:23,919] Trial 14 finished with value: 0.7210585781105248 and parameters: {'n_estimators': 290, 'max_depth': 3, 'learning_rate': 0.05539265783834485, 'subsample': 0.8617002750807236, 'colsample_bytree': 0.9127617299817429, 'gamma': 1.299996297362331, 'reg_alpha': 2.9353858127133168, 'reg_lambda': 3.3173297789608567}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:25,204] Trial 15 finished with value: 0.7185533011374419 and parameters: {'n_estimators': 253, 'max_depth': 3, 'learning_rate': 0.050679002624833464, 'subsample': 0.8461169294571441, 'colsample_bytree': 0.9642044231536145, 'gamma': 1.3981322484823822, 'reg_alpha': 1.4447823545812986, 'reg_lambda': 3.4590442647340973}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:25,204] Trial 15 finished with value: 0.7185533011374419 and parameters: {'n_estimators': 253, 'max_depth': 3, 'learning_rate': 0.050679002624833464, 'subsample': 0.8461169294571441, 'colsample_bytree': 0.9642044231536145, 'gamma': 1.3981322484823822, 'reg_alpha': 1.4447823545812986, 'reg_lambda': 3.4590442647340973}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:28,059] Trial 16 finished with value: 0.6819581533236275 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1462526103282827, 'subsample': 0.8235480288493601, 'colsample_bytree': 0.717334792600546, 'gamma': 0.9279704654436488, 'reg_alpha': 3.0111402622936025, 'reg_lambda': 2.6077226926550665}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:28,059] Trial 16 finished with value: 0.6819581533236275 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1462526103282827, 'subsample': 0.8235480288493601, 'colsample_bytree': 0.717334792600546, 'gamma': 0.9279704654436488, 'reg_alpha': 3.0111402622936025, 'reg_lambda': 2.6077226926550665}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:29,590] Trial 17 finished with value: 0.7198458634491947 and parameters: {'n_estimators': 257, 'max_depth': 3, 'learning_rate': 0.07824737624277722, 'subsample': 0.906972610581283, 'colsample_bytree': 0.9337173113813211, 'gamma': 1.92667537933615, 'reg_alpha': 2.104477397765357, 'reg_lambda': 3.8667770707859117}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:29,590] Trial 17 finished with value: 0.7198458634491947 and parameters: {'n_estimators': 257, 'max_depth': 3, 'learning_rate': 0.07824737624277722, 'subsample': 0.906972610581283, 'colsample_bytree': 0.9337173113813211, 'gamma': 1.92667537933615, 'reg_alpha': 2.104477397765357, 'reg_lambda': 3.8667770707859117}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:31,275] Trial 18 finished with value: 0.7089739908805784 and parameters: {'n_estimators': 255, 'max_depth': 5, 'learning_rate': 0.12774599031708966, 'subsample': 0.8045757456047149, 'colsample_bytree': 0.607924197278779, 'gamma': 3.23553662188596, 'reg_alpha': 0.009909497590825538, 'reg_lambda': 3.184397733945576}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:31,275] Trial 18 finished with value: 0.7089739908805784 and parameters: {'n_estimators': 255, 'max_depth': 5, 'learning_rate': 0.12774599031708966, 'subsample': 0.8045757456047149, 'colsample_bytree': 0.607924197278779, 'gamma': 3.23553662188596, 'reg_alpha': 0.009909497590825538, 'reg_lambda': 3.184397733945576}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:32,929] Trial 19 finished with value: 0.7181763512474064 and parameters: {'n_estimators': 299, 'max_depth': 2, 'learning_rate': 0.03957666608998729, 'subsample': 0.8991155088415954, 'colsample_bytree': 0.7294118092952403, 'gamma': 0.7455154632083304, 'reg_alpha': 3.347968567261491, 'reg_lambda': 2.1472417812620415}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:32,929] Trial 19 finished with value: 0.7181763512474064 and parameters: {'n_estimators': 299, 'max_depth': 2, 'learning_rate': 0.03957666608998729, 'subsample': 0.8991155088415954, 'colsample_bytree': 0.7294118092952403, 'gamma': 0.7455154632083304, 'reg_alpha': 3.347968567261491, 'reg_lambda': 2.1472417812620415}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:34,851] Trial 20 finished with value: 0.7160775684457703 and parameters: {'n_estimators': 223, 'max_depth': 6, 'learning_rate': 0.012145319176344191, 'subsample': 0.7770865190669083, 'colsample_bytree': 0.897347277691427, 'gamma': 2.923528244527577, 'reg_alpha': 1.261487593056879, 'reg_lambda': 3.1180518801907446}. Best is trial 14 with value: 0.7210585781105248.
# [I 2025-07-15 23:37:34,851] Trial 20 finished with value: 0.7160775684457703 and parameters: {'n_estimators': 223, 'max_depth': 6, 'learning_rate': 0.012145319176344191, 'subsample': 0.7770865190669083, 'colsample_bytree': 0.897347277691427, 'gamma': 2.923528244527577, 'reg_alpha': 1.261487593056879, 'reg_lambda': 3.1180518801907446}. Best is trial 14 with value: 0.7210585781105248.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:35] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:35] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:35,969] Trial 21 finished with value: 0.7218434538332208 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.06309350559680499, 'subsample': 0.8663343470444552, 'colsample_bytree': 0.8357769173807776, 'gamma': 1.0216922285082934, 'reg_alpha': 2.618458383109329, 'reg_lambda': 3.797118344624291}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:35,969] Trial 21 finished with value: 0.7218434538332208 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.06309350559680499, 'subsample': 0.8663343470444552, 'colsample_bytree': 0.8357769173807776, 'gamma': 1.0216922285082934, 'reg_alpha': 2.618458383109329, 'reg_lambda': 3.797118344624291}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:37,030] Trial 22 finished with value: 0.7164385422981703 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.10293751706782417, 'subsample': 0.8680812083419782, 'colsample_bytree': 0.8563340558257438, 'gamma': 1.7708956881180824, 'reg_alpha': 2.306158196616466, 'reg_lambda': 4.9761536264188555}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:37,030] Trial 22 finished with value: 0.7164385422981703 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.10293751706782417, 'subsample': 0.8680812083419782, 'colsample_bytree': 0.8563340558257438, 'gamma': 1.7708956881180824, 'reg_alpha': 2.306158196616466, 'reg_lambda': 4.9761536264188555}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:38,146] Trial 23 finished with value: 0.7150654815808976 and parameters: {'n_estimators': 244, 'max_depth': 4, 'learning_rate': 0.06545909634609134, 'subsample': 0.9561335294842657, 'colsample_bytree': 0.9281641730734411, 'gamma': 0.6201727274652623, 'reg_alpha': 1.830592214884116, 'reg_lambda': 4.073451166420283}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:38,146] Trial 23 finished with value: 0.7150654815808976 and parameters: {'n_estimators': 244, 'max_depth': 4, 'learning_rate': 0.06545909634609134, 'subsample': 0.9561335294842657, 'colsample_bytree': 0.9281641730734411, 'gamma': 0.6201727274652623, 'reg_alpha': 1.830592214884116, 'reg_lambda': 4.073451166420283}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:39,223] Trial 24 finished with value: 0.7196107781703422 and parameters: {'n_estimators': 272, 'max_depth': 3, 'learning_rate': 0.03825914612206976, 'subsample': 0.7899047355035891, 'colsample_bytree': 0.6877275036736237, 'gamma': 1.2642343817898658, 'reg_alpha': 3.241874267528805, 'reg_lambda': 3.2942160236450153}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:39,223] Trial 24 finished with value: 0.7196107781703422 and parameters: {'n_estimators': 272, 'max_depth': 3, 'learning_rate': 0.03825914612206976, 'subsample': 0.7899047355035891, 'colsample_bytree': 0.6877275036736237, 'gamma': 1.2642343817898658, 'reg_alpha': 3.241874267528805, 'reg_lambda': 3.2942160236450153}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:39,879] Trial 25 finished with value: 0.7175958126252215 and parameters: {'n_estimators': 202, 'max_depth': 2, 'learning_rate': 0.06361077914168696, 'subsample': 0.8806394787766102, 'colsample_bytree': 0.7680519167228155, 'gamma': 2.054505886453203, 'reg_alpha': 4.231530090043037, 'reg_lambda': 3.8034174561223484}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:39,879] Trial 25 finished with value: 0.7175958126252215 and parameters: {'n_estimators': 202, 'max_depth': 2, 'learning_rate': 0.06361077914168696, 'subsample': 0.8806394787766102, 'colsample_bytree': 0.7680519167228155, 'gamma': 2.054505886453203, 'reg_alpha': 4.231530090043037, 'reg_lambda': 3.8034174561223484}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:40] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:40] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:42,363] Trial 26 finished with value: 0.7003111390270587 and parameters: {'n_estimators': 235, 'max_depth': 5, 'learning_rate': 0.11587711376999632, 'subsample': 0.9359874689454287, 'colsample_bytree': 0.8411901979805047, 'gamma': 0.5929138404153076, 'reg_alpha': 2.5393635043205474, 'reg_lambda': 2.27012771582789}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:42,363] Trial 26 finished with value: 0.7003111390270587 and parameters: {'n_estimators': 235, 'max_depth': 5, 'learning_rate': 0.11587711376999632, 'subsample': 0.9359874689454287, 'colsample_bytree': 0.8411901979805047, 'gamma': 0.5929138404153076, 'reg_alpha': 2.5393635043205474, 'reg_lambda': 2.27012771582789}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:43,512] Trial 27 finished with value: 0.7082101670852756 and parameters: {'n_estimators': 268, 'max_depth': 4, 'learning_rate': 0.14218872962326268, 'subsample': 0.8283912548106535, 'colsample_bytree': 0.8146543532020242, 'gamma': 2.757775066011851, 'reg_alpha': 1.0172319230887539, 'reg_lambda': 4.313037455710864}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:43,512] Trial 27 finished with value: 0.7082101670852756 and parameters: {'n_estimators': 268, 'max_depth': 4, 'learning_rate': 0.14218872962326268, 'subsample': 0.8283912548106535, 'colsample_bytree': 0.8146543532020242, 'gamma': 2.757775066011851, 'reg_alpha': 1.0172319230887539, 'reg_lambda': 4.313037455710864}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:44,734] Trial 28 finished with value: 0.7179394438542819 and parameters: {'n_estimators': 292, 'max_depth': 3, 'learning_rate': 0.019946297951032088, 'subsample': 0.7678517078375554, 'colsample_bytree': 0.9226745952434854, 'gamma': 1.6284492792285135, 'reg_alpha': 2.9956109059542184, 'reg_lambda': 2.9318455621916515}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:44,734] Trial 28 finished with value: 0.7179394438542819 and parameters: {'n_estimators': 292, 'max_depth': 3, 'learning_rate': 0.019946297951032088, 'subsample': 0.7678517078375554, 'colsample_bytree': 0.9226745952434854, 'gamma': 1.6284492792285135, 'reg_alpha': 2.9956109059542184, 'reg_lambda': 2.9318455621916515}. Best is trial 21 with value: 0.7218434538332208.
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-07-15 23:37:45,199] Trial 29 finished with value: 0.7180871001858296 and parameters: {'n_estimators': 79, 'max_depth': 2, 'learning_rate': 0.16805601709784906, 'subsample': 0.9070235031498937, 'colsample_bytree': 0.7738006157314055, 'gamma': 1.0942383142968026, 'reg_alpha': 1.9243881274627608, 'reg_lambda': 2.5543841712356308}. Best is trial 21 with value: 0.7218434538332208.
# [I 2025-07-15 23:37:45,199] Trial 29 finished with value: 0.7180871001858296 and parameters: {'n_estimators': 79, 'max_depth': 2, 'learning_rate': 0.16805601709784906, 'subsample': 0.9070235031498937, 'colsample_bytree': 0.7738006157314055, 'gamma': 1.0942383142968026, 'reg_alpha': 1.9243881274627608, 'reg_lambda': 2.5543841712356308}. Best is trial 21 with value: 0.7218434538332208.
# Best trial:
# {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.06309350559680499, 'subsample': 0.8663343470444552, 'colsample_bytree': 0.8357769173807776, 'gamma': 1.0216922285082934, 'reg_alpha': 2.618458383109329, 'reg_lambda': 3.797118344624291}

# %% [markdown]
# ## Get the best params using Optuna

# %%
xgb_best = XGBClassifier(**best_params)
xgb_best.fit(X_train, y_train)
# Out:
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:45] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8357769173807776, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=1.0216922285082934, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.06309350559680499,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=273, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ## Test Prediction after XG-Boost Hyper-param

# %%
# Evaluate
y_pred = xgb_best.predict(X_test)
y_pred_proba = xgb_best.predict_proba(X_test)[:, 1]
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     13894
#            1       1.00      0.00      0.00      1106
#
#     accuracy                           0.93     15000
#    macro avg       0.96      0.50      0.48     15000
# weighted avg       0.93      0.93      0.89     15000

# %% [markdown]
# ## Apply SMOTE

# %%
# Apply SMOTE to balance the training data
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# Retrain XGBoost with best params on resampled data
xgb_best_smote = XGBClassifier(**best_params)
xgb_best_smote.fit(X_train_res, y_train_res)


y_pred = xgb_best_smote.predict(X_test)
y_pred_proba = xgb_best_smote.predict_proba(X_test)[:, 1]
print("Classification Report after SMOTE:\n", classification_report(y_test, y_pred))
auc = roc_auc_score(y_test, y_pred_proba)
print(f"AUC-ROC Score after SMOTE: {auc:.4f}")
# Out:
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Classification Report after SMOTE:
#                precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92     13894
#            1       0.12      0.17      0.14      1106
#
#     accuracy                           0.85     15000
#    macro avg       0.53      0.54      0.53     15000
# weighted avg       0.87      0.85      0.86     15000
#
# AUC-ROC Score after SMOTE: 0.6233

# %% [markdown]
# ## Apply Class Weights

# %%
# Compute class weights for XGBoost
from collections import Counter

# Calculate scale_pos_weight for XGBoost (ratio of negative to positive class)
class_counts = Counter(y_train_res)
scale_pos_weight = class_counts[0] / class_counts[1] if class_counts[1] != 0 else 1

# Add scale_pos_weight to best_params
tuned_params = best_params.copy()
tuned_params['scale_pos_weight'] = scale_pos_weight

# Retrain XGBoost with class weights
xgb_best_weighted = XGBClassifier(**tuned_params)
xgb_best_weighted.fit(X_train_res, y_train_res)

# Evaluate
y_pred = xgb_best_weighted.predict(X_test)
y_pred_proba = xgb_best_weighted.predict_proba(X_test)[:, 1]
print("Classification Report with class weights:\n", classification_report(y_test, y_pred))
# Out:
# c:\Users\sanmo\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:37:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Classification Report with class weights:
#                precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92     13894
#            1       0.12      0.17      0.14      1106
#
#     accuracy                           0.85     15000
#    macro avg       0.53      0.54      0.53     15000
# weighted avg       0.87      0.85      0.86     15000

# %% [markdown]
# ## Test Prediction by varying thershold

# %%
# Tune classification threshold for best F1-score on test set
import numpy as np
from sklearn.metrics import f1_score

probas = xgb_best_weighted.predict_proba(X_test)[:, 1]
thresholds = np.arange(0.1, 0.91, 0.01)
f1_scores = [f1_score(y_test, (probas >= t).astype(int)) for t in thresholds]
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f'Best threshold: {best_threshold:.2f}, Best F1-score: {best_f1:.4f}')

# Classification report at best threshold
y_pred_best = (probas >= best_threshold).astype(int)
print('Classification Report at best threshold:')
print(classification_report(y_test, y_pred_best))
# Out:
# Best threshold: 0.30, Best F1-score: 0.1785
# Classification Report at best threshold:
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82     13894
#            1       0.11      0.44      0.18      1106
#
#     accuracy                           0.70     15000
#    macro avg       0.53      0.58      0.50     15000
# weighted avg       0.88      0.70      0.77     15000

# %% [markdown]
# ## Apply Light gbm

# %%
# Train and evaluate LightGBM on resampled data
# !pip install lightgbm
import lightgbm as lgb

# Compute class weights for LightGBM
from collections import Counter
class_counts = Counter(y_train_res)
class_weight = {0: class_counts[1]/class_counts[0], 1: 1.0} if class_counts[0] != 0 else {0: 1.0, 1: 1.0}

lgbm = lgb.LGBMClassifier(random_state=42, class_weight=class_weight)
lgbm.fit(X_train_res, y_train_res)

# Predict probabilities and tune threshold
probas = lgbm.predict_proba(X_test)[:, 1]
thresholds = np.arange(0.1, 0.91, 0.01)
f1_scores = [f1_score(y_test, (probas >= t).astype(int)) for t in thresholds]
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f'Best threshold (LightGBM): {best_threshold:.2f}, Best F1-score: {best_f1:.4f}')

y_pred_best = (probas >= best_threshold).astype(int)
print('Classification Report (LightGBM) at best threshold:')
print(classification_report(y_test, y_pred_best))
# Out:
# [LightGBM] [Info] Number of positive: 32434, number of negative: 32434
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008786 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6712
# [LightGBM] [Info] Number of data points in the train set: 64868, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Best threshold (LightGBM): 0.21, Best F1-score: 0.1922
# Classification Report (LightGBM) at best threshold:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87     13894
#            1       0.13      0.36      0.19      1106
#
#     accuracy                           0.78     15000
#    macro avg       0.54      0.59      0.53     15000
# weighted avg       0.88      0.78      0.82     15000
#
# Best threshold (LightGBM): 0.21, Best F1-score: 0.1922
# Classification Report (LightGBM) at best threshold:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87     13894
#            1       0.13      0.36      0.19      1106
#
#     accuracy                           0.78     15000
#    macro avg       0.54      0.59      0.53     15000
# weighted avg       0.88      0.78      0.82     15000
